# %%
from epdatapro import *
from matplotlib import pyplot as plt
from matplotlib import cm
months =["Jan","Feb","Mar","Apr","May","Jun","Jul","Aug","Sep","Oct","Nov","Dec"]

yy = "2015"
rp = r"D:\Cornell\EthiopianDrought\Chirps2"
rpp = r"D:\Cornell\EthiopianDrought\AData\Chirps2Pars"

smp = r"D:\Cornell\EthiopianDrought\AData\ESACCIV0.4.5"
smpp = r"D:\Cornell\EthiopianDrought\AData\ESACCIPars"

etp = r"D:\Cornell\BessMonthClip"
etpp = r"D:\Cornell\EthiopianDrought\AData\BessETMonthPars"

etp2 = r"D:\Cornell\EthiopianDrought\AData\ETClip"
etpp2 =  r"D:\Cornell\EthiopianDrought\AData\ETMonthPars"

ep = r"D:\Cornell\EthiopianDrought\MOD13C2.006Ethiopia"
epp = r"D:\Cornell\EthiopianDrought\AData\MOD13C2.006EthiopiaAnomalyPars"

sp = r"D:\Cornell\EthiopianDrought\AData\NewSIF0318AnomSplit"
spp = r"D:\Cornell\EthiopianDrought\AData\NewSIFMonthPars"

gsif =r'D:\Cornell\EthiopianDrought\AData\GOSIF0317AnomSplit'
gsifp =r'D:\Cornell\EthiopianDrought\AData\GOSIFMonthPars'

fig = plt.figure(figsize=(16,20))
plt.title("{} Anomaly Map Include Bess and Gleam ET".format(yy)+'\n', fontsize=20)

for m in range(2,6):
    ramn = chirpsAnomalyMap(rp,rpp,yy,str(m))
    ax = fig.add_subplot(7, 4, m-1) 
    ax.set_title("Precipitaion_"+months[m-1])
    mask = np.where(ramn > -9999)
    ramn[ramn == -9999] = np.nan
    vmin = ramn[mask].min()
    vmax = ramn[mask].max()
    print("maxmin value",vmin,vmax)
    cmap = plt.get_cmap("RdBu")
    
    cax = ax.imshow(ramn,cmap=cmap,vmin=-2.5,vmax=2.5)
#     cbar = plt.colorbar(cax,ax=ax) 
    ax.set_xticks([])
    ax.set_yticks([])

for m in range(2,6):
    smamn = esacciAnomalyMap(smp,smpp,yy,str(m))
    ax = fig.add_subplot(7, 4, m-1+4) 
    ax.set_title("SM_"+months[m-1])
    mask = np.where(smamn > -9999)
    smamn[smamn == -9999] = np.nan
    vmin = smamn[mask].min()
    vmax = smamn[mask].max()
    print("maxmin value",vmin,vmax)
    cax = ax.imshow(smamn,cmap=plt.get_cmap("RdBu"),vmin=-2.5,vmax=2.5)
#     cbar = plt.colorbar(cax,ax=ax)
    ax.set_xticks([])
    ax.set_yticks([])
for m in range(2,6):
    etamn = BessETAnomalyMap(etp,etpp,yy,str(m))
    ax = fig.add_subplot(7, 4, m-1+8) 
    ax.set_title("Bess ET_"+months[m-1])
    mask = np.where(etamn > -9999)
    etamn[etamn == -9999] = np.nan
    vmin = etamn[mask].min()
    vmax = etamn[mask].max()
    print("maxmin value",vmin,vmax)
    cax = ax.imshow(etamn,cmap=plt.get_cmap("RdBu"),vmin=-2.5,vmax=2.5)
#     cbar = plt.colorbar(cax,ax=ax)
    ax.set_xticks([])
    ax.set_yticks([])
    
for m in range(2,6):
    etamn = etAnomalyMap(etp2,etpp2,yy,str(m))
    ax = fig.add_subplot(7, 4, m-1+12) 
    ax.set_title("ET_"+months[m-1])
    mask = np.where(etamn > -9999)
    etamn[etamn == -9999] = np.nan
    vmin = etamn[mask].min()
    vmax = etamn[mask].max()
    print("maxmin value",vmin,vmax)
    cax = ax.imshow(etamn,cmap=plt.get_cmap("RdBu"),vmin=-2.5,vmax=2.5)
#     cbar = plt.colorbar(cax,ax=ax)
    ax.set_xticks([])
    ax.set_yticks([])
    
for m in range(2,6):
    samn = NewSIFAnomalyMap(sp,spp,yy,str(m))
    ax = fig.add_subplot(7, 4, m-1+16) 
    ax.set_title("New SIF_"+months[m-1])
    mask = np.where(samn > -9999)
    samn[samn == -9999] = np.nan
    vmin = samn[mask].min()
    vmax = samn[mask].max()
    print("maxmin value",vmin,vmax)
    cax = ax.imshow(samn,cmap=plt.get_cmap("RdBu"),vmin=-2.5,vmax=2.5)
#     cbar = plt.colorbar(cax,ax=ax)
    ax.set_xticks([])
    ax.set_yticks([])
for m in range(2,6):
    eamn = eviAnomalyMap(ep,epp,yy,str(m))
    ax = fig.add_subplot(7, 4, m-1+20) 
    ax.set_title("EVI_"+months[m-1])
    mask = np.where(eamn > -9999)
    eamn[eamn == -9999] = np.nan
    vmin = eamn[mask].min()
    vmax = eamn[mask].max()
#     print("maxmin value",vmin,vmax)
    cax = ax.imshow(eamn,cmap=plt.get_cmap("RdBu"),vmin=-2.5,vmax=2.5)
#     cbar = plt.colorbar(cax,ax=ax)
    ax.set_xticks([])
    ax.set_yticks([])
for m in range(2,6):
    eamn = GOSIFAnomalyMap(gsif,gsifp,yy,str(m))
    ax = fig.add_subplot(7, 4, m-1+24) 
    ax.set_title("GOSIF_"+months[m-1])
    mask = np.where(eamn > -9999)
    eamn[eamn == -9999] = np.nan
    vmin = eamn[mask].min()
    vmax = eamn[mask].max()
#     print("maxmin value",vmin,vmax)
    cax = ax.imshow(eamn,cmap=plt.get_cmap("RdBu"),vmin=-2.5,vmax=2.5)
#     cbar = plt.colorbar(cax,ax=ax)
    ax.set_xticks([])
    ax.set_yticks([])
    
    

fig.tight_layout()#调整整体空白 
plt.show()
# Out:
# get the monthly parameters from file D:\Cornell\EthiopianDrought\AData\Chirps2Pars\chirps_month02.tif
# maxmin value -1.2877461910247803 3.2696373462677
# get the monthly parameters from file D:\Cornell\EthiopianDrought\AData\Chirps2Pars\chirps_month03.tif
# maxmin value -1.505162239074707 3.8641557693481445
# get the monthly parameters from file D:\Cornell\EthiopianDrought\AData\Chirps2Pars\chirps_month04.tif
# maxmin value -2.038964033126831 2.1329896450042725
# get the monthly parameters from file D:\Cornell\EthiopianDrought\AData\Chirps2Pars\chirps_month05.tif
# maxmin value -1.7413523197174072 2.6580612659454346
# maxmin value -2.0885279178619385 2.1847381591796875
# maxmin value -1.9844982624053955 2.8969054222106934
# maxmin value -2.6169683933258057 2.425502300262451
# maxmin value -1.9061046838760376 1.9339617490768433
# maxmin value -3.2002360820770264 3.3465001583099365
# maxmin value -3.111783981323242 3.3737952709198
# maxmin value -3.3408267498016357 3.33469557762146
# maxmin value -3.2413365840911865 3.2191779613494873
# maxmin value -2.714531898498535 2.7924814224243164
# maxmin value -1.9154478311538696 3.0030548572540283
# maxmin value -2.9033310413360596 1.7245019674301147
# maxmin value -2.39377760887146 1.9877763986587524
# maxmin value -2.4848172664642334 2.5489022731781006
# maxmin value -2.678964138031006 1.4539830684661865
# maxmin value -2.4438130855560303 2.583894729614258
# maxmin value -2.701298952102661 2.4374496936798096
# D:\Cornell\EthiopianDrought\AData\GOSIF0317AnomSplit\2015GOSIF_Anom02.tif
# D:\Cornell\EthiopianDrought\AData\GOSIF0317AnomSplit\2015GOSIF_Anom03.tif
# D:\Cornell\EthiopianDrought\AData\GOSIF0317AnomSplit\2015GOSIF_Anom04.tif
# D:\Cornell\EthiopianDrought\AData\GOSIF0317AnomSplit\2015GOSIF_Anom05.tif

# %%
from epdatapro import *
from matplotlib import pyplot as plt
from matplotlib import cm
months =["Jan","Feb","Mar","Apr","May","Jun","Jul","Aug","Sep","Oct","Nov","Dec"]

yy = "2015"
rp = r"D:\Cornell\EthiopianDrought\Chirps2"
rpp = r"D:\Cornell\EthiopianDrought\AData\Chirps2Pars"

smp = r"D:\Cornell\EthiopianDrought\AData\ESACCIV0.4.5"
smpp = r"D:\Cornell\EthiopianDrought\AData\ESACCIPars"

etp = r"D:\Cornell\BessMonthClip"
etpp = r"D:\Cornell\EthiopianDrought\AData\BessETMonthPars"

etp2 = r"D:\Cornell\EthiopianDrought\AData\ETClip"
etpp2 =  r"D:\Cornell\EthiopianDrought\AData\ETMonthPars"


ep = r"D:\Cornell\EthiopianDrought\MOD13C2.006Ethiopia"
epp = r"D:\Cornell\EthiopianDrought\AData\MOD13C2.006EthiopiaAnomalyPars"

sp = r"D:\Cornell\EthiopianDrought\AData\NewSIF0318AnomSplit"
spp = r"D:\Cornell\EthiopianDrought\AData\NewSIFMonthPars"

gsif =r'D:\Cornell\EthiopianDrought\AData\GOSIF0317AnomSplit'
gsifp =r'D:\Cornell\EthiopianDrought\AData\GOSIFMonthPars'

fig = plt.figure(figsize=(16,20))
plt.title("{} Anomaly Map Include Bess and Gleam ET".format(yy)+'\n', fontsize=20)

for m in range(6,10):
    ramn = chirpsAnomalyMap(rp,rpp,yy,str(m))
    ax = fig.add_subplot(7, 4, m-5) 
    ax.set_title("Precipitaion_"+months[m-1])
    mask = np.where(ramn > -9999)
    ramn[ramn == -9999] = np.nan
    vmin = ramn[mask].min()
    vmax = ramn[mask].max()
    print("maxmin value",vmin,vmax)
    cax = ax.imshow(ramn,cmap=plt.get_cmap("RdBu"),vmin=-2.5,vmax=2.5)
#     cbar = plt.colorbar(cax,ax=ax) 
    ax.set_xticks([])
    ax.set_yticks([])

for m in range(6,10):
    smamn = esacciAnomalyMap(smp,smpp,yy,str(m))
    ax = fig.add_subplot(7, 4, m-1+4-4) 
    ax.set_title("SM_"+months[m-1])
    mask = np.where(smamn > -9999)
    smamn[smamn == -9999] = np.nan
    vmin = smamn[mask].min()
    vmax = smamn[mask].max()
    print("maxmin value",vmin,vmax)
    cax = ax.imshow(smamn,cmap=plt.get_cmap("RdBu"),vmin=-2.5,vmax=2.5)
#     cbar = plt.colorbar(cax,ax=ax)
    ax.set_xticks([])
    ax.set_yticks([])
for m in range(6,10):
    etamn = BessETAnomalyMap(etp,etpp,yy,str(m))
    ax = fig.add_subplot(7, 4, m-1+8-4) 
    ax.set_title("Bess ET_"+months[m-1])
    mask = np.where(etamn > -9999)
    etamn[etamn == -9999] = np.nan
    vmin = etamn[mask].min()
    vmax = etamn[mask].max()
    print("maxmin value",vmin,vmax)
    cax = ax.imshow(etamn,cmap=plt.get_cmap("RdBu"),vmin=-2.5,vmax=2.5)
#     cbar = plt.colorbar(cax,ax=ax)
    ax.set_xticks([])
    ax.set_yticks([])
    
for m in range(6,10):
    etamn = etAnomalyMap(etp2,etpp2,yy,str(m))
    ax = fig.add_subplot(7, 4, m-5+12) 
    ax.set_title("Gleam ET_"+months[m-1])
    mask = np.where(etamn > -9999)
    etamn[etamn == -9999] = np.nan
    vmin = etamn[mask].min()
    vmax = etamn[mask].max()
    print("maxmin value",vmin,vmax)
    cax = ax.imshow(etamn,cmap=plt.get_cmap("RdBu"),vmin=-2.5,vmax=2.5)
#     cbar = plt.colorbar(cax,ax=ax)
    ax.set_xticks([])
    ax.set_yticks([])
    
    
for m in range(6,10):
    samn = NewSIFAnomalyMap(sp,spp,yy,str(m))
    ax = fig.add_subplot(7, 4, m-1+16-4) 
    ax.set_title("New SIF_"+months[m-1])
    mask = np.where(samn > -9999)
    samn[samn == -9999] = np.nan
    vmin = samn[mask].min()
    vmax = samn[mask].max()
    print("maxmin value",vmin,vmax)
    cax = ax.imshow(samn,cmap=plt.get_cmap("RdBu"),vmin=-2.5,vmax=2.5)
#     cbar = plt.colorbar(cax,ax=ax)
    ax.set_xticks([])
    ax.set_yticks([])
for m in range(6,10):
    eamn = eviAnomalyMap(ep,epp,yy,str(m))
    ax = fig.add_subplot(7, 4, m-1+20-4) 
    ax.set_title("EVI_"+months[m-1])
    mask = np.where(eamn > -9999)
    eamn[eamn == -9999] = np.nan
    vmin = eamn[mask].min()
    vmax = eamn[mask].max()
#     print("maxmin value",vmin,vmax)
    cax = ax.imshow(eamn,cmap=plt.get_cmap("RdBu"),vmin=-2.5,vmax=2.5)
#     cbar = plt.colorbar(cax,ax=ax)
    ax.set_xticks([])
    ax.set_yticks([])
for m in range(6,10):
    eamn = GOSIFAnomalyMap(gsif,gsifp,yy,str(m))
    ax = fig.add_subplot(7, 4, m-1+24-4) 
    ax.set_title("GOSIF_"+months[m-1])
    mask = np.where(eamn > -9999)
    eamn[eamn == -9999] = np.nan
    vmin = eamn[mask].min()
    vmax = eamn[mask].max()
#     print("maxmin value",vmin,vmax)
    cax = ax.imshow(eamn,cmap=plt.get_cmap("RdBu"),vmin=-2.5,vmax=2.5)
#     cbar = plt.colorbar(cax,ax=ax)
    ax.set_xticks([])
    ax.set_yticks([])
    
    

fig.tight_layout()#调整整体空白 
plt.show()
# Out:
# get the monthly parameters from file D:\Cornell\EthiopianDrought\AData\Chirps2Pars\chirps_month06.tif
# maxmin value -2.5110394954681396 3.785828113555908
# get the monthly parameters from file D:\Cornell\EthiopianDrought\AData\Chirps2Pars\chirps_month07.tif
# maxmin value -3.1030941009521484 3.0552995204925537
# get the monthly parameters from file D:\Cornell\EthiopianDrought\AData\Chirps2Pars\chirps_month08.tif
# maxmin value -3.1700069904327393 3.8666231632232666
# get the monthly parameters from file D:\Cornell\EthiopianDrought\AData\Chirps2Pars\chirps_month09.tif
# maxmin value -2.6302289962768555 3.252410411834717
# maxmin value -2.094748020172119 2.4019675254821777
# maxmin value -3.2297616004943848 2.0315427780151367
# maxmin value -3.2695624828338623 2.058427572250366
# maxmin value -2.402743101119995 2.593310832977295
# maxmin value -2.910033702850342 3.3770787715911865
# maxmin value -3.25459885597229 3.413760185241699
# maxmin value -3.301654815673828 3.380850076675415
# maxmin value -3.4308409690856934 3.361215591430664
# maxmin value -1.766064167022705 3.4823081493377686
# maxmin value -3.200103759765625 3.1022891998291016
# maxmin value -2.6834049224853516 3.4485926628112793
# maxmin value -2.641036033630371 3.1993935108184814
# maxmin value -2.135366678237915 2.4784722328186035
# maxmin value -2.8749184608459473 3.078929901123047
# maxmin value -2.8813931941986084 2.817227602005005
# maxmin value -3.1018221378326416 3.3983237743377686
# D:\Cornell\EthiopianDrought\AData\GOSIF0317AnomSplit\2015GOSIF_Anom06.tif
# D:\Cornell\EthiopianDrought\AData\GOSIF0317AnomSplit\2015GOSIF_Anom07.tif
# D:\Cornell\EthiopianDrought\AData\GOSIF0317AnomSplit\2015GOSIF_Anom08.tif
# D:\Cornell\EthiopianDrought\AData\GOSIF0317AnomSplit\2015GOSIF_Anom09.tif
