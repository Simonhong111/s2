# %%
from epdatapro import *
from matplotlib import pyplot as plt
from matplotlib import cm
months =["Jan","Feb","Mar","Apr","May","Jun","Jul","Aug","Sep","Oct","Nov","Dec"]

# %%
rp = r"D:\Cornell\EthiopianDrought\Chirps2"
rpp = r"D:\Cornell\EthiopianDrought\AData\Chirps2Pars"

smp = r"D:\Cornell\EthiopianDrought\AData\ESACCIV0.4.5"
smpp = r"D:\Cornell\EthiopianDrought\AData\ESACCIPars"

etp = r"D:\Cornell\EthiopianDrought\AData\ETClip"
etpp = r"D:\Cornell\EthiopianDrought\AData\ETMonthPars"

ep = r"D:\Cornell\EthiopianDrought\MOD13C2.006Ethiopia"
epp = r"D:\Cornell\EthiopianDrought\AData\MOD13C2.006EthiopiaAnomalyPars"

sp = r"D:\Cornell\EthiopianDrought\clipedSIf"
spp = r"D:\Cornell\EthiopianDrought\AData\SIFPars"

fig = plt.figure(figsize=(20,16))


for m in range(2,6):
    ave,year = chirpsAnomalySeries(rp,str(m))
    ax = fig.add_subplot(5, 4, m-1) 
    ax.set_title("Precipitation_"+months[m-1])
    ax.plot(year,ave,label= months[m-1])
    ax.grid(True)
    ax.legend()
    xmin, xmax, ymin, ymax = ax.axis()
    ax.vlines([2015,2016,2017,2018], ymin, ymax,colors="r")
    ax.plot([xmin,xmax],[0,0],"k")
    ax.set_xticks(year)
    ax.set_xticklabels(year) 
    for xtick in ax.get_xticklabels():
        xtick.set_rotation(90)
for m in range(2,6):
    ave,year = esacciAnomalySeries(smp,str(m))
    ax = fig.add_subplot(5, 4, m-1+4) 
    ax.set_title("SM_"+months[m-1])
    ax.plot(year,ave,label= months[m-1])
    ax.grid(True)
    ax.legend()
    xmin, xmax, ymin, ymax = ax.axis()
    ax.vlines([2015,2016,2017,2018], ymin, ymax,colors="r")
    ax.plot([xmin,xmax],[0,0],"k")
    ax.set_xticks(year)
    ax.set_xticklabels(year) 
    for xtick in ax.get_xticklabels():
        xtick.set_rotation(90)
for m in range(2,6):
    ave,year = etAnomalySeries(etp,str(m))
    ax = fig.add_subplot(5, 4, m-1+8) 
    ax.set_title("ET_"+months[m-1])
    ax.plot(year,ave,label= months[m-1])
    ax.grid(True)
    ax.legend()
    xmin, xmax, ymin, ymax = ax.axis()
    ax.vlines([2015,2016,2017,2018], ymin, ymax,colors="r")
    ax.plot([xmin,xmax],[0,0],"k")
    ax.set_xticks(year)
    ax.set_xticklabels(year) 
    for xtick in ax.get_xticklabels():
        xtick.set_rotation(90)
for m in range(2,6):
    ave,year = sifAnomalySeries(sp,str(m))
    ax = fig.add_subplot(5, 4, m-1+12) 
    ax.set_title("SIF_"+months[m-1])
    ax.plot(year,ave,label= months[m-1])
    ax.grid(True)
    ax.legend()
    xmin, xmax, ymin, ymax = ax.axis()
    ax.vlines([2015,2016,2017,2018], ymin, ymax,colors="r")
    ax.plot([xmin,xmax],[0,0],"k")
    ax.set_xticks(year)
    ax.set_xticklabels(year) 
    for xtick in ax.get_xticklabels():
        xtick.set_rotation(90)

for m in range(2,6):
    ave,year = eviAnomalySeries(ep,str(m))
    ax = fig.add_subplot(5, 4, m-1+16) 
    ax.set_title("EVI_"+months[m-1])
    ax.plot(year,ave,label= months[m-1])
    ax.grid(True)
    ax.legend()
    xmin, xmax, ymin, ymax = ax.axis()
    ax.vlines([2015,2016,2017,2018], ymin, ymax,colors="r")
    ax.plot([xmin,xmax],[0,0],"k")
    ax.set_xticks(year)
    ax.set_xticklabels(year) 
    for xtick in ax.get_xticklabels():
        xtick.set_rotation(90)

fig.tight_layout()#调整整体空白 
plt.show()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-2-cfbffcb6367d> in <module>
#      33         xtick.set_rotation(90)
#      34 for m in range(2,6):
# ---> 35     ave,year = esacciAnomalySeries(smp,str(m))
#      36     ax = fig.add_subplot(5, 4, m-1+4)
#      37     ax.set_title("SM_"+months[m-1])
#
# D:\Cornell\EthiopiaDrought\epdatapro.py in esacciAnomalySeries(chirpsdirectory, month)
#     860             # maskarr[mask] = maskarr[mask] + 1
#     861             multidarr[:, :, band_id] = modis
# --> 862             multidarr[:,:,band_id][crop != 12] = -2
#     863             axisTime.append(dt.year)
#     864             del modis
#
# IndexError: boolean index did not match indexed array along dimension 0; dimension is 45 but corresponding boolean dimension is 228

# %%
rp = r"D:\Cornell\EthiopianDrought\Chirps2"
rpp = r"D:\Cornell\EthiopianDrought\AData\Chirps2Pars"

smp = r"D:\Cornell\EthiopianDrought\AData\ESACCIV0.4.5"
smpp = r"D:\Cornell\EthiopianDrought\AData\ESACCIPars"

etp = r"D:\Cornell\EthiopianDrought\AData\ETClip"
etpp = r"D:\Cornell\EthiopianDrought\AData\ETMonthPars"

ep = r"D:\Cornell\EthiopianDrought\MOD13C2.006Ethiopia"
epp = r"D:\Cornell\EthiopianDrought\AData\MOD13C2.006EthiopiaAnomalyPars"

sp = r"D:\Cornell\EthiopianDrought\clipedSIf"
spp = r"D:\Cornell\EthiopianDrought\AData\SIFPars"

fig = plt.figure(figsize=(20,16))


for m in range(6,10):
    ave,year = chirpsAnomalySeries(rp,str(m))
    ax = fig.add_subplot(5, 4, m-5) 
    ax.set_title("Precipitation_"+months[m-1])
    ax.plot(year,ave,label= months[m-1])
    ax.grid(True)
    ax.legend()
    xmin, xmax, ymin, ymax = ax.axis()
    ax.vlines([2015,2016,2017,2018], ymin, ymax,colors="r")
    ax.plot([xmin,xmax],[0,0],"k")
    ax.set_xticks(year)
    ax.set_xticklabels(year) 
    for xtick in ax.get_xticklabels():
        xtick.set_rotation(90)
for m in range(6,10):
    ave,year = esacciAnomalySeries(smp,str(m))
    ax = fig.add_subplot(5, 4, m-5+4) 
    ax.set_title("SM_"+months[m-1])
    ax.plot(year,ave,label= months[m-1])
    ax.grid(True)
    ax.legend()
    xmin, xmax, ymin, ymax = ax.axis()
    ax.vlines([2015,2016,2017,2018], ymin, ymax,colors="r")
    ax.plot([xmin,xmax],[0,0],"k")
    ax.set_xticks(year)
    ax.set_xticklabels(year) 
    for xtick in ax.get_xticklabels():
        xtick.set_rotation(90)
for m in range(6,10):
    ave,year = etAnomalySeries(etp,str(m))
    ax = fig.add_subplot(5, 4, m-5+8) 
    ax.set_title("ET_"+months[m-1])
    ax.plot(year,ave,label= months[m-1])
    ax.grid(True)
    ax.legend()
    xmin, xmax, ymin, ymax = ax.axis()
    ax.vlines([2015,2016,2017,2018], ymin, ymax,colors="r")
    ax.plot([xmin,xmax],[0,0],"k")
    ax.set_xticks(year)
    ax.set_xticklabels(year) 
    for xtick in ax.get_xticklabels():
        xtick.set_rotation(90)
for m in range(6,10):
    ave,year = sifAnomalySeries(sp,str(m))
    ax = fig.add_subplot(5, 4, m-5+12) 
    ax.set_title("SIF_"+months[m-1])
    ax.plot(year,ave,label= months[m-1])
    ax.grid(True)
    ax.legend()
    xmin, xmax, ymin, ymax = ax.axis()
    ax.vlines([2015,2016,2017,2018], ymin, ymax,colors="r")
    ax.plot([xmin,xmax],[0,0],"k")
    ax.set_xticks(year)
    ax.set_xticklabels(year) 
    for xtick in ax.get_xticklabels():
        xtick.set_rotation(90)

for m in range(6,10):
    ave,year = eviAnomalySeries(ep,str(m))
    ax = fig.add_subplot(5, 4, m-5+16) 
    ax.set_title("EVI_"+months[m-1])
    ax.plot(year,ave,label= months[m-1])
    ax.grid(True)
    ax.legend()
    xmin, xmax, ymin, ymax = ax.axis()
    ax.vlines([2015,2016,2017,2018], ymin, ymax,colors="r")
    ax.plot([xmin,xmax],[0,0],"k")
    ax.set_xticks(year)
    ax.set_xticklabels(year) 
    for xtick in ax.get_xticklabels():
        xtick.set_rotation(90)

fig.tight_layout()#调整整体空白 
plt.show()
