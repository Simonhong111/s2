# %%
from epdatapro2007 import *
from matplotlib import pyplot as plt
from matplotlib import cm
months =["Jan","Feb","Mar","Apr","May","Jun","Jul","Aug","Sep","Oct","Nov","Dec"]
rp = r"D:\Cornell\EthiopianDrought\Chirps2"
rpp = r"D:\Cornell\EthiopianDrought\AData\Chirps2Pars"

smp = r"D:\Cornell\EthiopianDrought\AData\ESACCIV0.4.5"
smpp = r"D:\Cornell\EthiopianDrought\AData\ESACCIPars"

etp = r"D:\Cornell\EthiopianDrought\AData\ETClip"
etpp = r"D:\Cornell\EthiopianDrought\AData\ETMonthPars"

ep = r"D:\Cornell\EthiopianDrought\MOD13C2.006Ethiopia"
epp = r"D:\Cornell\EthiopianDrought\AData\MOD13C2.006EthiopiaAnomalyPars"

sp =  r"D:\Cornell\EthiopianDrought\AData\NewSIF0318AnomSplit2007"
spp =  r"D:\Cornell\EthiopianDrought\AData\NewSIFMonthPars2007"




gsif =r'D:\Cornell\EthiopianDrought\AData\GOSIF0317AnomSplit'
gsifp =r'D:\Cornell\EthiopianDrought\AData\GOSIFMonthPars'

fig = plt.figure(figsize=(20,16))


for m in range(2,6):
    ave,year = chirpsAnomalySeries(rp,str(m))
    ax = fig.add_subplot(6, 4, m-1) 
    ax.set_title("Precipitation_"+months[m-1])
    ax.plot(year,ave,label= months[m-1])
    ax.grid(True)
    ax.legend()
    xmin, xmax, ymin, ymax = ax.axis()
    ax.vlines([2015,2016,2017,2018], ymin, ymax,colors="r")
    ax.plot([xmin,xmax],[0,0],"k")
    ax.set_xticks(year)
    ax.set_xticklabels(year) 
    for xtick in ax.get_xticklabels():
        xtick.set_rotation(90)
for m in range(2,6):
    ave,year = esacciAnomalySeries(smp,str(m))
    ax = fig.add_subplot(6, 4, m-1+4) 
    ax.set_title("SM_"+months[m-1])
    ax.plot(year,ave,label= months[m-1])
    ax.grid(True)
    ax.legend()
    xmin, xmax, ymin, ymax = ax.axis()
    ax.vlines([2015,2016,2017,2018], ymin, ymax,colors="r")
    ax.plot([xmin,xmax],[0,0],"k")
    ax.set_xticks(year)
    ax.set_xticklabels(year) 
    for xtick in ax.get_xticklabels():
        xtick.set_rotation(90)
for m in range(2,6):
    ave,year = etAnomalySeries(etp,str(m))
    ax = fig.add_subplot(6, 4, m-1+8) 
    ax.set_title("ET_"+months[m-1])
    ax.plot(year,ave,label= months[m-1])
    ax.grid(True)
    ax.legend()
    xmin, xmax, ymin, ymax = ax.axis()
    ax.vlines([2015,2016,2017,2018], ymin, ymax,colors="r")
    ax.plot([xmin,xmax],[0,0],"k")
    ax.set_xticks(year)
    ax.set_xticklabels(year) 
    for xtick in ax.get_xticklabels():
        xtick.set_rotation(90)
for m in range(2,6):
    ave,year = NewSIFAnomalySeries(sp,str(m))
    ax = fig.add_subplot(6, 4, m-1+12) 
    ax.set_title("NewSIF_"+months[m-1])
    ax.plot(year,ave,label= months[m-1])
    ax.grid(True)
    ax.legend()
    xmin, xmax, ymin, ymax = ax.axis()
    ax.vlines([2015,2016,2017,2018], ymin, ymax,colors="r")
    ax.plot([xmin,xmax],[0,0],"k")
    ax.set_xticks(year)
    ax.set_xticklabels(year) 
    for xtick in ax.get_xticklabels():
        xtick.set_rotation(90)
        xtick.set_rotation(90)
for m in range(2,6):
    ave,year = GOSIFAnomalySeries(gsif,str(m))
    ax = fig.add_subplot(6, 4, m-1+16) 
    ax.set_title("GOSIF_"+months[m-1])
    ax.plot(year,ave,label= months[m-1])
    ax.grid(True)
    ax.legend()
    xmin, xmax, ymin, ymax = ax.axis()
    ax.vlines([2015,2016,2017,2018], ymin, ymax,colors="r")
    ax.plot([xmin,xmax],[0,0],"k")
    ax.set_xticks(year)
    ax.set_xticklabels(year) 
    for xtick in ax.get_xticklabels():
        xtick.set_rotation(90)
for m in range(2,6):
    ave,year = eviAnomalySeries(ep,str(m))
    ax = fig.add_subplot(6, 4, m-1+20) 
    ax.set_title("EVI_"+months[m-1])
    ax.plot(year,ave,label= months[m-1])
    ax.grid(True)
    ax.legend()
    xmin, xmax, ymin, ymax = ax.axis()
    ax.vlines([2015,2016,2017,2018], ymin, ymax,colors="r")
    ax.plot([xmin,xmax],[0,0],"k")
    ax.set_xticks(year)
    ax.set_xticklabels(year) 
    for xtick in ax.get_xticklabels():
        xtick.set_rotation(90)

fig.tight_layout()#调整整体空白 
plt.show()

# %%
from epdatapro2007 import *
from matplotlib import pyplot as plt
from matplotlib import cm
rp = r"D:\Cornell\EthiopianDrought\Chirps2"
rpp = r"D:\Cornell\EthiopianDrought\AData\Chirps2Pars"

smp = r"D:\Cornell\EthiopianDrought\AData\ESACCIV0.4.5"
smpp = r"D:\Cornell\EthiopianDrought\AData\ESACCIPars"

etp = r"D:\Cornell\EthiopianDrought\AData\ETClip"
etpp = r"D:\Cornell\EthiopianDrought\AData\ETMonthPars"

ep = r"D:\Cornell\EthiopianDrought\MOD13C2.006Ethiopia"
epp = r"D:\Cornell\EthiopianDrought\AData\MOD13C2.006EthiopiaAnomalyPars"

sp =  r"D:\Cornell\EthiopianDrought\AData\NewSIF0318AnomSplit"
spp =  r"D:\Cornell\EthiopianDrought\AData\NewSIFMonthPars"



gsif =r'D:\Cornell\EthiopianDrought\AData\GOSIF0317AnomSplit'
gsifp =r'D:\Cornell\EthiopianDrought\AData\GOSIFMonthPars'

fig = plt.figure(figsize=(20,16))


for m in range(6,10):
    ave,year = chirpsAnomalySeries(rp,str(m))
    ax = fig.add_subplot(6, 4, m-5) 
    ax.set_title("Precipitation_"+months[m-1])
    ax.plot(year,ave,label= months[m-1])
    ax.grid(True)
    ax.legend()
    xmin, xmax, ymin, ymax = ax.axis()
    ax.vlines([2015,2016,2017,2018], ymin, ymax,colors="r")
    ax.plot([xmin,xmax],[0,0],"k")
    ax.set_xticks(year)
    ax.set_xticklabels(year) 
    for xtick in ax.get_xticklabels():
        xtick.set_rotation(90)
for m in range(6,10):
    ave,year = esacciAnomalySeries(smp,str(m))
    ax = fig.add_subplot(6, 4, m-5+4) 
    ax.set_title("SM_"+months[m-1])
    ax.plot(year,ave,label= months[m-1])
    ax.grid(True)
    ax.legend()
    xmin, xmax, ymin, ymax = ax.axis()
    ax.vlines([2015,2016,2017,2018], ymin, ymax,colors="r")
    ax.plot([xmin,xmax],[0,0],"k")
    ax.set_xticks(year)
    ax.set_xticklabels(year) 
    for xtick in ax.get_xticklabels():
        xtick.set_rotation(90)
for m in range(6,10):
    ave,year = etAnomalySeries(etp,str(m))
    ax = fig.add_subplot(6, 4, m-5+8) 
    ax.set_title("ET_"+months[m-1])
    ax.plot(year,ave,label= months[m-1])
    ax.grid(True)
    ax.legend()
    xmin, xmax, ymin, ymax = ax.axis()
    ax.vlines([2015,2016,2017,2018], ymin, ymax,colors="r")
    ax.plot([xmin,xmax],[0,0],"k")
    ax.set_xticks(year)
    ax.set_xticklabels(year) 
    for xtick in ax.get_xticklabels():
        xtick.set_rotation(90)
for m in range(6,10):
    ave,year =  NewSIFAnomalySeries(sp,str(m))
    ax = fig.add_subplot(6, 4, m-5+12) 
    ax.set_title("NewSIF_"+months[m-1])
    ax.plot(year,ave,label= months[m-1])
    ax.grid(True)
    ax.legend()
    xmin, xmax, ymin, ymax = ax.axis()
    ax.vlines([2015,2016,2017,2018], ymin, ymax,colors="r")
    ax.plot([xmin,xmax],[0,0],"k")
    ax.set_xticks(year)
    ax.set_xticklabels(year) 
    for xtick in ax.get_xticklabels():
        xtick.set_rotation(90)
for m in range(6,10):
    ave,year = GOSIFAnomalySeries(gsif,str(m))
    ax = fig.add_subplot(6, 4, m-5+16) 
    ax.set_title("GOSIF_"+months[m-1])
    ax.plot(year,ave,label= months[m-1])
    ax.grid(True)
    ax.legend()
    xmin, xmax, ymin, ymax = ax.axis()
    ax.vlines([2015,2016,2017,2018], ymin, ymax,colors="r")
    ax.plot([xmin,xmax],[0,0],"k")
    ax.set_xticks(year)
    ax.set_xticklabels(year) 
    for xtick in ax.get_xticklabels():
        xtick.set_rotation(90)

for m in range(6,10):
    ave,year = eviAnomalySeries(ep,str(m))
    ax = fig.add_subplot(6, 4, m-5+20) 
    ax.set_title("EVI_"+months[m-1])
    ax.plot(year,ave,label= months[m-1])
    ax.grid(True)
    ax.legend()
    xmin, xmax, ymin, ymax = ax.axis()
    ax.vlines([2015,2016,2017,2018], ymin, ymax,colors="r")
    ax.plot([xmin,xmax],[0,0],"k")
    ax.set_xticks(year)
    ax.set_xticklabels(year) 
    for xtick in ax.get_xticklabels():
        xtick.set_rotation(90)

fig.tight_layout()#调整整体空白 
plt.show()
